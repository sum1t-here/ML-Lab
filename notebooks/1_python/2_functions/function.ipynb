# %%
# functions:
# inbuilt -> print, len, type etc
# userdefined

# %%
int(2.25)
# Out:
# 2

# %%
float(2)
# Out:
# 2.0

# %%
import math as m
m.ceil(6.5)
# Out:
# 7

# %%
m.floor(6.5)
# Out:
# 6

# %%
#syntax of function

# def func():
    # do something
    # do something
    # return

# %%
def greet(n):
    print("Welcome to class", n)

# %%
greet("Bona")
# Out:
# Welcome to class Bona

# %%
type(greet)
# Out:
# function

# %%
def func():
    return "this is my first function", 2, 4, 3+7j, True

# %%
a = func()
a
# Out:
# ('this is my first function', 2, 4, (3+7j), True)

# %%
type(a)
# Out:
# tuple

# %%
a, b, c, d, e = func()

# %%
a
# Out:
# 'this is my first function'

# %%
b
# Out:
# 2

# %%
c
# Out:
# 4

# %%
d
# Out:
# (3+7j)

# %%
e
# Out:
# True

# %%
def func():
    calc = 2*3*6*5
    return calc

# %%
type(func())
# Out:
# int

# %%
# default arguement

def sum(a=0, b=0, c=0):
    return a+b+c

# %%
type(sum())
# Out:
# int

# %%
sum()
# Out:
# 0

# %%
sum(1,2,3)
# Out:
# 6

# %%
# a function that take list as input and return all numeric value
def only_numeric(a):
    n = []
    for i in a:
        if type(i) == int or type(i) == float:
            n.append(i)
    return n

# %%
only_numeric([1, 2, 3, 4, 5, 6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
only_numeric([1, 2, 3, 4.5, 5, [1, 2, 3, 4,], "Machine learning"])
# Out:
# [1, 2, 3, 4.5, 5]

# %%
# modified
def only_numeric(a):
    n = []
    for i in a:
        if type(i) == list:
            for j in i:
                if type(j) == int or type(j) == float:
                    n.append(j)
        else:
            if type(i) == int or type(i) == float:
                n.append(i)
    return n

# %%
only_numeric([1, 2, 3, 4.5, 5, [1, 2, 3, 4,], "Machine learning"])
# Out:
# [1, 2, 3, 4.5, 5, 1, 2, 3, 4]

# %%
def test(*args):
    return args

# %%
test([1, 2, 3, 4.5, 5, [1, 2, 3, 4,], "Machine learning"])
# Out:
# ([1, 2, 3, 4.5, 5, [1, 2, 3, 4], 'Machine learning'],)

# %%
def test(*args, a):
    return args, a

# %%
test(1, 2, 3, 4.5, 5, [1, 2, 3, 4,], "Machine learning", a = True)
# Out:
# ((1, 2, 3, 4.5, 5, [1, 2, 3, 4], 'Machine learning'), True)

# %%
# it should accept any number of arguments
# treated as key vlaue pair

def kwarg_func(**kwargs):
    return kwargs

# %%
kwarg_func(a = 2, b = 3, c = [1,2,3])
# Out:
# {'a': 2, 'b': 3, 'c': [1, 2, 3]}

# %%
# returns a value which is a list

def test(**kwargs):
    for i in kwargs.keys():
        if type(kwargs[i]) == list:
            return i, kwargs[i]

# %%
test(a = 2, b = 3, c = [1,2,3])
# Out:
# ('c', [1, 2, 3])

# %%
def test(*arg, **kwargs):
    """ This function returns arg and kwargs
    Args:
    Kwargs
    """
    return arg, kwargs

# %%
test(1,2,4, a=100, c=200)
# Out:
# ((1, 2, 4), {'a': 100, 'c': 200})

# %%
help(test)
# Out:
# Help on function test in module __main__:
#
# test(*arg, **kwargs)
#     This function returns arg and kwargs
#     Args:
#     Kwargs

# %%
print(test.__doc__)
# Out:
#  This function returns arg and kwargs
#     Args:
#     Kwargs
