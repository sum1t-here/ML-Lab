# %%
# dictionary is a data structure that stores data as key value pair
# unordered, keys are unique and immutable

# %%
d = {}
type(d)
# Out:
# dict

# %%
d = {"name" : "gnayu", "email" : "g@andu.com", "contact": 1234}
d
# Out:
# {'name': 'gnayu', 'email': 'g@andu.com', 'contact': 1234}

# %%
l = [100, 200, 300]

# %%
l[0]
# Out:
# 100

# %%
d["name"]
# Out:
# 'gnayu'

# %%
d["name"] = "anndG"
d
# Out:
# {'name': 'anndG', 'email': 'g@andu.com', 'contact': 1234}

# %%
d.keys()
# Out:
# dict_keys(['name', 'email', 'contact'])

# %%
d.values()
# Out:
# dict_values(['anndG', 'g@andu.com', 1234])

# %%
d.items()
# Out:
# dict_items([('name', 'anndG'), ('email', 'g@andu.com'), ('contact', 1234)])

# %%
dl = d.copy()

# %%
dl
# Out:
# {'name': 'anndG', 'email': 'g@andu.com', 'contact': 1234}

# %%
del dl

# %%
d
# Out:
# {'name': 'anndG', 'email': 'g@andu.com', 'contact': 1234}

# %%
d.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 d.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d.pop("contact")
# Out:
# 1234

# %%
d
# Out:
# {'name': 'anndG', 'email': 'g@andu.com'}

# %%
dl = {"course" : "DS", "start" : "20th March"}
dl
# Out:
# {'course': 'DS', 'start': '20th March'}

# %%
d.update(dl)
d
# Out:
# {'name': 'anndG', 'email': 'g@andu.com', 'course': 'DS', 'start': '20th March'}

# %%
d.get("start")
# Out:
# '20th March'

# %%
d.fromkeys((1,2,3),('a', 'b', 'c'))
# Out:
# {1: ('a', 'b', 'c'), 2: ('a', 'b', 'c'), 3: ('a', 'b', 'c')}

# %%
# dictionary comprehension

students = ["Og", "Bg", "FoG"]
marks = [80, 85, 90]

student_marks = {}

for student, mark in zip(students, marks):
    print(zip(students, marks))
    student_marks[student] = mark
# Out:
# <zip object at 0x103e7cdc0>
# <zip object at 0x103e7cdc0>
# <zip object at 0x103e7cdc0>

# %%
student_marks
# Out:
# {'Og': 80, 'Bg': 85, 'FoG': 90}

# %%
for i in zip(students, marks):
    print(i)
# Out:
# ('Og', 80)
# ('Bg', 85)
# ('FoG', 90)

# %%
{student:marks for student, marks in zip(students, marks)}
# Out:
# {'Og': 80, 'Bg': 85, 'FoG': 90}

# %%
user_id = [1,2,3]
user_name = ["a21", "a22", "a23"]
{u_id:u_name for u_id, u_name in zip(user_id, user_name)}
# Out:
# {1: 'a21', 2: 'a22', 3: 'a23'}
