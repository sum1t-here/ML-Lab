# %% [markdown]
# # Strings
#
# A sequence of character

# %%
# ASCII Representation
char = "A"
ord(char)
# Out:
# 65

# %%
ord("a")
# Out:
# 97

# %%
chr(101)
# Out:
# 'e'

# %%
#UNICODE Representation
'\u03A9'
# Out:
# 'Ω'

# %%
string1 = 'pwskills'
type(string1)
# Out:
# str

# %%
# concatenation

str1 = "hello"
str2 = " world"
str3 = str1 + str2
str3
# Out:
# 'hello world'

# %%
#Extract a string
str3[0:5]
# Out:
# 'hello'

# %%
str3[1:]
# Out:
# 'ello world'

# %%
str3[-1]
# Out:
# 'd'

# %%
# Except last three characters
str3[:-3]
# Out:
# 'hello wo'

# %%
str3[0:7:2]
# Out:
# 'hlow'

# %%
str3[0]
# Out:
# 'h'

# %%
str3[0] = "t"  # strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 str3[0] = "t"
#
# TypeError: 'str' object does not support item assignment

# %%
len(str3)
# Out:
# 11

# %%
# modification of a string
s = "I am a student"
s.replace("student", "teacher")
# Out:
# 'I am a teacher'

# %%
str3.upper()
# Out:
# 'HELLO WORLD'

# %%
str3.capitalize()
# Out:
# 'Hello world'

# %%
"world" in str3
# Out:
# True

# %%
s = "       hello                "
s.strip()
# Out:
# 'hello'

# %%
s = "apple, mango, tree"

# %%
info = s.split(',')
info
# Out:
# ['apple', ' mango', ' tree']

# %%
# string namespace
price = 24.9
print(f"The price of is ${price}")
# Out:
# The price of is $24.9
