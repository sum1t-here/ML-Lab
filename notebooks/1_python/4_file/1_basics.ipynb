# %%
# r -> read mode
# w -> write mode
# a -> appending mode
# r+ -> both reading and writing

file = open("file.txt", "w")

# %%
file.write("This is my first line") # number below represents no of bytes
# Out:
# 21

# %%
file.close()

# %%
# file attributes
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='UTF-8'>

# %%
file.closed
# Out:
# True

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'w'

# %%
file = open("file.txt", "r")

# %%
for i in file:
    print(i)
# Out:
# This is my first line

# %%
print(file.read()) # where the cursor or pointer at last pos

# %%
file.tell()
# Out:
# 21

# %%
file.read()
# Out:
# ''

# %%
file.seek(0) # moves the file pointer back to the beginning of the file.
# Out:
# 0

# %%
file.read()
# Out:
# 'This is my first line'

# %%
f = open("file.txt", "r")
print(f.readline())
f.close()
# Out:
# This is my first line

# %%
import os

# %%
pwd
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file'

# %%
os.getcwd()
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file'

# %%
ls
# Out:
# 1_basics.ipynb  file.txt

# %%
os.path.getsize("file.txt")
# Out:
# 21

# %%
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
os.makedirs("1/2/3")

# %%
os.listdir()
# Out:
# ['file.txt', 'test', '1', '1_basics.ipynb']

# %%
os.mkdir("feat")

# %%
os.rmdir("feat")

# %%
import shutil
shutil.rmtree("1")

# %%
os.getcwd()
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file'

# %%
pwd
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file'

# %%
f = open("/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/test/test1/file_test.txt", "w")

# %%
shutil.copy("/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/test/test1/file_test.txt", "/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/file.txt")
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/file.txt'

# %%
os.mkdir("test_move")

# %%
shutil.move("/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/test/test1/file_test.txt", "/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/file.txt")
# Out:
# '/Users/sumithere/Desktop/coding/ML-Lab/notebooks/1_python/4_file/file.txt'

# %%
os.remove("file_test.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 os.remove("file_test.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file_test.txt'

# %%
with open("file.txt", "r") as f:
    line = f.readline()
    print(line)
